# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('resources/country_full.csv')

# %%
df.loc[91:91]
# Out:
#          name alpha-2 alpha-3  country-code     iso_3166-2    region  \
# 91  Guatemala      GT     GTM           320  ISO 3166-2:GT  Americas
#
#                          sub-region intermediate-region  region-code  \
# 91  Latin America and the Caribbean     Central America         19.0
#
#     sub-region-code  intermediate-region-code
# 91            419.0                      13.0

# %%
df[['name', 'sub-region']]
# Out:
#                   name          sub-region
# 0          Afghanistan       Southern Asia
# 1        Åland Islands     Northern Europe
# 2              Albania     Southern Europe
# 3              Algeria     Northern Africa
# 4       American Samoa           Polynesia
# ..                 ...                 ...
# 244  Wallis and Futuna           Polynesia
# 245     Western Sahara     Northern Africa
# 246              Yemen        Western Asia
# 247             Zambia  Sub-Saharan Africa
# 248           Zimbabwe  Sub-Saharan Africa
#
# [249 rows x 2 columns]

# %%
df['intermediate-region-code']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 244     NaN
# 245     NaN
# 246     NaN
# 247    14.0
# 248    14.0
# Name: intermediate-region-code, Length: 249, dtype: float64

# %%
df.head(10)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2    region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX    Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS   Oceania
# 5              Andorra      AD     AND            20  ISO 3166-2:AD    Europe
# 6               Angola      AO     AGO            24  ISO 3166-2:AO    Africa
# 7             Anguilla      AI     AIA           660  ISO 3166-2:AI  Americas
# 8           Antarctica      AQ     ATA            10  ISO 3166-2:AQ       NaN
# 9  Antigua and Barbuda      AG     ATG            28  ISO 3166-2:AG  Americas
#
#                         sub-region intermediate-region  region-code  \
# ...

# %%
df['sub-region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sub-region'>
